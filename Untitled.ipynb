# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
players <- read_csv("players.csv")
sessions <- read_csv("sessions.csv")
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
players_numeric <- players |>
    select(played_hours, Age)
players_numeric
# Out:
#     played_hours Age
# 1   30.3          9
# 2    3.8         17
# 3    0.0         17
# 4    0.7         21
# 5    0.1         21
# 6    0.0         17
# 7    0.0         19
# 8    0.0         21
# 9    0.1         47
# 10   0.0         22
# 11   1.6         23
# 12   0.0         17
# 13   1.5         25
# 14   0.2         22
# 15   0.0         17
# 16   0.0         22
# 17   0.0         17
# 18  48.4         17
# 19   0.5         17
# 20   0.6         19
# 21   0.3         58
# 22   0.1         17
# 23   1.0         17
# 24   0.0         17
# 25   0.7         21
# 26   0.6         28
# 27   0.0         17
# 28   0.0         23
# 29   1.8         23
# 30   0.1         18
# ⋮   ⋮            ⋮
# 167  1.0         26
# 168  0.3         17
# 169  0.1         17
# 170  0.1         17
# 171  0.4         21
# 172  1.8         32
# 173  0.0         20
# 174  0.0         50
# 175  0.0         17
# 176  0.3         17
# 177  0.0         17
# 178  2.7         21
# 179  0.4         17
# ...

# %%
nrow(players)
nrow(sessions)
# Out:
# [1] 196
# [1] 1535

# %%
colMeans(players_numeric, na.rm = TRUE)
# Out:
# played_hours          Age
#     5.845918    21.139175

# %%
subscribed <- filter(players, subscribe == TRUE)
nrow(subscribed)
# Out:
# [1] 144

# %%
gender_male <- filter(players, gender == "Male")
nrow(gender_male)
gender_female <- filter(players, gender == "Female")
nrow(gender_female)
gender_nonbinary <- filter(players, gender == "Non-binary") 
nrow(gender_nonbinary)
gender_unknown <- filter(players, gender == "Prefer not to say")
nrow(gender_unknown)
gender_twospirited <- filter(players, gender == "Two-Spirited")
nrow(gender_twospirited)
gender_agender <- filter(players, gender == "Agender")
nrow(gender_agender)
gender_other <- filter(players, gender == "Other") 
nrow(gender_other)
# Out:
# [1] 124
# [1] 37
# [1] 15
# [1] 11
# [1] 6
# [1] 2
# [1] 1

# %% [markdown]
# The Purpose of this project is to be able to inferentiate about players based on the data that they provide us in order to be able to make for a better user experience and market toward players for a data analysis. We have 2 data frames to base our analysis upon, both information on players information and total playtime, and the second is information on individual sessions logged on the server. We have 196 players registered, and a total of 1535 sessions played. For the players quantitative variables, we have a average of 5.85 hours played and an average age amongst players of 21.14 years. Additional data within the players dataframe shows us that 144 of the players are subscribed to the newsletter, and there are 127 male players, 37 female players, 15 non-binary players, 11 people who prefer not to say, 6 Two-Spitired players, 2 Agender players, and 1 player who responded "Other"
